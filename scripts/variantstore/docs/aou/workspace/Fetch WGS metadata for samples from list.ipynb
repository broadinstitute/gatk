# %% [markdown]
# # Fetch WGS metadata for samples from list
#
# This notebook is intended to be run from a workspace to pull in metadata from the WGS QC workspace, given a file containing a list of samples to pull.
#
# Please copy this notebook into your workspace and run it there.

# %%
# uncomment and run this if you get an error importing toolz - you'll need to restart your notebook kernel after runniing this cell
# !pip install toolz
# !ls -l
# Out:
# Requirement already satisfied: toolz in /opt/conda/lib/python3.10/site-packages (0.12.0)
# total 188836
# -rw-rw-r-- 1 welder-user users    18391 Oct 12 19:42 'Fetch WGS metadata for samples from list.ipynb'
# -rw-rw-r-- 1 welder-user users     5076 Oct 12 19:05 'Parse Delcho Sample List.ipynb'
# -rw-rw-r-- 1 jupyter     users     1498 Oct 12 15:55  parse_delcho_sample_tsv.py
# -rw-rw-r-- 1 jupyter     users 96701674 Oct 12 15:55  wgs_all_terra_delcho_v1_Oct042023_1420_10_tz0000.tsv
# -rw-rw-r-- 1 jupyter     users 96632331 Oct 12 16:02  wgs_pass_qc_terra_filtered_except_is_missing_from_cdr_delcho_v1_Oct042023_1420_10_tz0000.tsv

# %%
import os
import json
import math
from firecloud import api as fapi
from pprint import pprint
from tqdm import tqdm
import pandas as pd
from toolz.itertoolz import partition_all

# %% [markdown]
# ## Set up source and target workspace info. You don't need to edit anything in the following cell, assuming this notebook lives in the workspace to which you'd like to copy the metadata

# %%
# the data will be copied TO the workspace in which the notebook is run
target_ws_project = os.environ['WORKSPACE_NAMESPACE']
target_ws_name = os.environ['WORKSPACE_NAME']
target_ws_bucket = os.environ['WORKSPACE_BUCKET']

# the data will be copied FROM the WGS QC workspace
source_ws_project = "allofus-drc-wgs-prod"
source_ws_name = "AoU_DRC_WGS"
source_ws_bucket = "gs://fc-secure-089622a2-ae22-4dc8-ad01-634bd7634d5f"

print(f"will copy data from {source_ws_project}/{source_ws_name} to {target_ws_project}/{target_ws_name}")
# Out:
# will copy data from allofus-drc-wgs-prod/AoU_DRC_WGS to allofus-drc-wgs-dev/GVS AoU Echo RD

# %% [markdown]
# ## Define and fetch the file that contains the list of samples you want to fetch

# %%
# EDIT THIS: localize the file containing requested samples
sample_list_file_path = "gs://fc-secure-4c3976f3-d84d-4243-876f-baa9f9a4256f/wgs_pass_qc_terra_filtered_except_is_missing_from_cdr_delcho_v1_Oct042023_1420_10_tz0000.tsv"

sample_list_file = sample_list_file_path.split("/")[-1]
# !gsutil cp $sample_list_file_path $sample_list_file
# !cat $sample_list_file | wc -l
# !head $sample_list_file -n 3
# Out:
# Copying gs://fc-secure-4c3976f3-d84d-4243-876f-baa9f9a4256f/wgs_pass_qc_terra_filtered_except_is_missing_from_cdr_delcho_v1_Oct042023_1420_10_tz0000.tsv...
# | [1 files][ 92.2 MiB/ 92.2 MiB]
# Operation completed over 1 objects/92.2 MiB.
# 382517
# 	research_id	drc_qc_status_wgs	aw2_processing_status_wgs	blocklist_reason_wgs	blocklist_flag_wgs	sample_source_wgs	drc_qc_status_array	aw2_processing_status_array	blocklist_reason_array	blocklist_flag_array	sample_source_array	sample_source	site_id	reblocked_gvcf	sample_id	flt_is_missing_from_cdr	flt_is_rid_duped	flt_suspicious_gvcf_path	flt_suspicious_rgvcf_path	flt_no_array_in_spot	flt_no_array_in_terra	flt_is_manual_blacklist
# 0	1000000						PASS	PASS		FALSE	WHOLE BLOOD	Whole Blood	bi	gs://prod-genomics-data-broad/ss_vcf_research/BI_A703323229_22088001176_1233191826_1.hard-filtered.gvcf.gz.reblocked.g.vcf.gz	1000000.22088001176	False	False	False	False	False	False	False
# 1	1000004						PASS	PASS		FALSE	WHOLE BLOOD	Whole Blood	bi	gs://prod-genomics-data-broad/ss_vcf_research/BI_A934715970_21092004350_0370947305_1.hard-filtered.gvcf.gz.reblocked.g.vcf.gz	1000004.21092004350	False	False	False	False	False	False	False

# %% [markdown]
# ## Extract the list of sample_ids from your file.
# NOTE: depending on how your input file was formed, you may need to do some munging to get the sample_id format - for short read WGS samples, the sample_id in Terra is composed of {research_id}.{aou_sample_id}

# %%
# extract just the list of samples
df_samples = pd.read_csv(sample_list_file, sep='\t', dtype=str)
df_samples.head()
sample_list = list(df_samples['sample_id'])


print(len(sample_list))
print(sample_list[:3])
# Out:
# 382516
# ['1000000.22088001176', '1000004.21092004350', '1000033.21075004006']

# %% [markdown]
# ## Perform the copy, in batches.
# Feel free to edit the batch size if it helps performance.

# %%
# copy data in batches
batch_size = 1000
total_copied = 0

for subset_sample_list in partition_all(batch_size, sample_list): 
    fapi.copy_entities(source_ws_project, source_ws_name, target_ws_project, target_ws_name, 
                       "sample", subset_sample_list, link_existing_entities=False)
    total_copied += len(subset_sample_list)
    print(f"copied {total_copied} samples out of {len(sample_list)}")
# Out:
# copied 1000 samples out of 382516
# copied 2000 samples out of 382516
# copied 3000 samples out of 382516
# copied 4000 samples out of 382516
# copied 5000 samples out of 382516
# copied 6000 samples out of 382516
# copied 7000 samples out of 382516
# copied 8000 samples out of 382516
# copied 9000 samples out of 382516
# copied 10000 samples out of 382516
# copied 11000 samples out of 382516
# copied 12000 samples out of 382516
# copied 13000 samples out of 382516
# copied 14000 samples out of 382516
# copied 15000 samples out of 382516
# copied 16000 samples out of 382516
# copied 17000 samples out of 382516
# copied 18000 samples out of 382516
# copied 19000 samples out of 382516
# copied 20000 samples out of 382516
# copied 21000 samples out of 382516
# copied 22000 samples out of 382516
# copied 23000 samples out of 382516
# copied 24000 samples out of 382516
# copied 25000 samples out of 382516
# copied 26000 samples out of 382516
# copied 27000 samples out of 382516
# copied 28000 samples out of 382516
# copied 29000 samples out of 382516
# copied 30000 samples out of 382516
# copied 31000 samples out of 382516
# copied 32000 samples out of 382516
# copied 33000 samples out of 382516
# copied 34000 samples out of 382516
# copied 35000 samples out of 382516
# copied 36000 samples out of 382516
# copied 37000 samples out of 382516
# copied 38000 samples out of 382516
# copied 39000 samples out of 382516
# copied 40000 samples out of 382516
# copied 41000 samples out of 382516
# copied 42000 samples out of 382516
# copied 43000 samples out of 382516
# copied 44000 samples out of 382516
# copied 45000 samples out of 382516
# copied 46000 samples out of 382516
# copied 47000 samples out of 382516
# copied 48000 samples out of 382516
# copied 49000 samples out of 382516
# copied 50000 samples out of 382516
# copied 51000 samples out of 382516
# copied 52000 samples out of 382516
# copied 53000 samples out of 382516
# copied 54000 samples out of 382516
# copied 55000 samples out of 382516
# copied 56000 samples out of 382516
# copied 57000 samples out of 382516
# copied 58000 samples out of 382516
# copied 59000 samples out of 382516
# copied 60000 samples out of 382516
# copied 61000 samples out of 382516
# copied 62000 samples out of 382516
# copied 63000 samples out of 382516
# copied 64000 samples out of 382516
# copied 65000 samples out of 382516
# copied 66000 samples out of 382516
# copied 67000 samples out of 382516
# copied 68000 samples out of 382516
# copied 69000 samples out of 382516
# copied 70000 samples out of 382516
# copied 71000 samples out of 382516
# copied 72000 samples out of 382516
# copied 73000 samples out of 382516
# copied 74000 samples out of 382516
# copied 75000 samples out of 382516
# copied 76000 samples out of 382516
# copied 77000 samples out of 382516
# copied 78000 samples out of 382516
# copied 79000 samples out of 382516
# copied 80000 samples out of 382516
# copied 81000 samples out of 382516
# copied 82000 samples out of 382516
# copied 83000 samples out of 382516
# copied 84000 samples out of 382516
# copied 85000 samples out of 382516
# copied 86000 samples out of 382516
# copied 87000 samples out of 382516
# copied 88000 samples out of 382516
# copied 89000 samples out of 382516
# copied 90000 samples out of 382516
# copied 91000 samples out of 382516
# copied 92000 samples out of 382516
# copied 93000 samples out of 382516
# copied 94000 samples out of 382516
# copied 95000 samples out of 382516
# copied 96000 samples out of 382516
# copied 97000 samples out of 382516
# copied 98000 samples out of 382516
# copied 99000 samples out of 382516
# copied 100000 samples out of 382516
# copied 101000 samples out of 382516
# copied 102000 samples out of 382516
# copied 103000 samples out of 382516
# copied 104000 samples out of 382516
# copied 105000 samples out of 382516
# copied 106000 samples out of 382516
# copied 107000 samples out of 382516
# copied 108000 samples out of 382516
# copied 109000 samples out of 382516
# copied 110000 samples out of 382516
# copied 111000 samples out of 382516
# copied 112000 samples out of 382516
# copied 113000 samples out of 382516
# copied 114000 samples out of 382516
# copied 115000 samples out of 382516
# copied 116000 samples out of 382516
# copied 117000 samples out of 382516
# copied 118000 samples out of 382516
# copied 119000 samples out of 382516
# copied 120000 samples out of 382516
# copied 121000 samples out of 382516
# copied 122000 samples out of 382516
# copied 123000 samples out of 382516
# copied 124000 samples out of 382516
# copied 125000 samples out of 382516
# copied 126000 samples out of 382516
# copied 127000 samples out of 382516
# copied 128000 samples out of 382516
# copied 129000 samples out of 382516
# copied 130000 samples out of 382516
# copied 131000 samples out of 382516
# copied 132000 samples out of 382516
# copied 133000 samples out of 382516
# copied 134000 samples out of 382516
# copied 135000 samples out of 382516
# copied 136000 samples out of 382516
# copied 137000 samples out of 382516
# copied 138000 samples out of 382516
# copied 139000 samples out of 382516
# copied 140000 samples out of 382516
# copied 141000 samples out of 382516
# copied 142000 samples out of 382516
# copied 143000 samples out of 382516
# copied 144000 samples out of 382516
# copied 145000 samples out of 382516
# copied 146000 samples out of 382516
# copied 147000 samples out of 382516
# copied 148000 samples out of 382516
# copied 149000 samples out of 382516
# copied 150000 samples out of 382516
# copied 151000 samples out of 382516
# copied 152000 samples out of 382516
# copied 153000 samples out of 382516
# copied 154000 samples out of 382516
# copied 155000 samples out of 382516
# copied 156000 samples out of 382516
# copied 157000 samples out of 382516
# copied 158000 samples out of 382516
# copied 159000 samples out of 382516
# copied 160000 samples out of 382516
# copied 161000 samples out of 382516
# copied 162000 samples out of 382516
# copied 163000 samples out of 382516
# copied 164000 samples out of 382516
# copied 165000 samples out of 382516
# copied 166000 samples out of 382516
# copied 167000 samples out of 382516
# copied 168000 samples out of 382516
# copied 169000 samples out of 382516
# copied 170000 samples out of 382516
# copied 171000 samples out of 382516
# copied 172000 samples out of 382516
# copied 173000 samples out of 382516
# copied 174000 samples out of 382516
# copied 175000 samples out of 382516
# copied 176000 samples out of 382516
# copied 177000 samples out of 382516
# copied 178000 samples out of 382516
# copied 179000 samples out of 382516
# copied 180000 samples out of 382516
# copied 181000 samples out of 382516
# copied 182000 samples out of 382516
# copied 183000 samples out of 382516
# copied 184000 samples out of 382516
# copied 185000 samples out of 382516
# copied 186000 samples out of 382516
# copied 187000 samples out of 382516
# copied 188000 samples out of 382516
# copied 189000 samples out of 382516
# copied 190000 samples out of 382516
# copied 191000 samples out of 382516
# copied 192000 samples out of 382516
# copied 193000 samples out of 382516
# copied 194000 samples out of 382516
# copied 195000 samples out of 382516
# copied 196000 samples out of 382516
# copied 197000 samples out of 382516
# copied 198000 samples out of 382516
# copied 199000 samples out of 382516
# copied 200000 samples out of 382516
# copied 201000 samples out of 382516
# copied 202000 samples out of 382516
# copied 203000 samples out of 382516
# copied 204000 samples out of 382516
# copied 205000 samples out of 382516
# copied 206000 samples out of 382516
# copied 207000 samples out of 382516
# copied 208000 samples out of 382516
# copied 209000 samples out of 382516
# copied 210000 samples out of 382516
# copied 211000 samples out of 382516
# copied 212000 samples out of 382516
# copied 213000 samples out of 382516
# copied 214000 samples out of 382516
# copied 215000 samples out of 382516
# copied 216000 samples out of 382516
# copied 217000 samples out of 382516
# copied 218000 samples out of 382516
# copied 219000 samples out of 382516
# copied 220000 samples out of 382516
# copied 221000 samples out of 382516
# copied 222000 samples out of 382516
# copied 223000 samples out of 382516
# copied 224000 samples out of 382516
# copied 225000 samples out of 382516
# copied 226000 samples out of 382516
# copied 227000 samples out of 382516
# copied 228000 samples out of 382516
# copied 229000 samples out of 382516
# copied 230000 samples out of 382516
# copied 231000 samples out of 382516
# copied 232000 samples out of 382516
# copied 233000 samples out of 382516
# copied 234000 samples out of 382516
# copied 235000 samples out of 382516
# copied 236000 samples out of 382516
# copied 237000 samples out of 382516
# copied 238000 samples out of 382516
# copied 239000 samples out of 382516
# copied 240000 samples out of 382516
# copied 241000 samples out of 382516
# copied 242000 samples out of 382516
# copied 243000 samples out of 382516
# copied 244000 samples out of 382516
# copied 245000 samples out of 382516
# copied 246000 samples out of 382516
# copied 247000 samples out of 382516
# copied 248000 samples out of 382516
# copied 249000 samples out of 382516
# copied 250000 samples out of 382516
# copied 251000 samples out of 382516
# copied 252000 samples out of 382516
# copied 253000 samples out of 382516
# copied 254000 samples out of 382516
# copied 255000 samples out of 382516
# copied 256000 samples out of 382516
# copied 257000 samples out of 382516
# copied 258000 samples out of 382516
# copied 259000 samples out of 382516
# copied 260000 samples out of 382516
# copied 261000 samples out of 382516
# copied 262000 samples out of 382516
# copied 263000 samples out of 382516
# copied 264000 samples out of 382516
# copied 265000 samples out of 382516
# copied 266000 samples out of 382516
# copied 267000 samples out of 382516
# copied 268000 samples out of 382516
# copied 269000 samples out of 382516
# copied 270000 samples out of 382516
# copied 271000 samples out of 382516
# copied 272000 samples out of 382516
# copied 273000 samples out of 382516
# copied 274000 samples out of 382516
# copied 275000 samples out of 382516
# copied 276000 samples out of 382516
# copied 277000 samples out of 382516
# copied 278000 samples out of 382516
# copied 279000 samples out of 382516
# copied 280000 samples out of 382516
# copied 281000 samples out of 382516
# copied 282000 samples out of 382516
# copied 283000 samples out of 382516
# copied 284000 samples out of 382516
# copied 285000 samples out of 382516
# copied 286000 samples out of 382516
# copied 287000 samples out of 382516
# copied 288000 samples out of 382516
# copied 289000 samples out of 382516
# copied 290000 samples out of 382516
# copied 291000 samples out of 382516
# copied 292000 samples out of 382516
# copied 293000 samples out of 382516
# copied 294000 samples out of 382516
# copied 295000 samples out of 382516
# copied 296000 samples out of 382516
# copied 297000 samples out of 382516
# copied 298000 samples out of 382516
# copied 299000 samples out of 382516
# copied 300000 samples out of 382516
# copied 301000 samples out of 382516
# copied 302000 samples out of 382516
# copied 303000 samples out of 382516
# copied 304000 samples out of 382516
# copied 305000 samples out of 382516
# copied 306000 samples out of 382516
# copied 307000 samples out of 382516
# copied 308000 samples out of 382516
# copied 309000 samples out of 382516
# copied 310000 samples out of 382516
# copied 311000 samples out of 382516
# copied 312000 samples out of 382516
# copied 313000 samples out of 382516
# copied 314000 samples out of 382516
# copied 315000 samples out of 382516
# copied 316000 samples out of 382516
# copied 317000 samples out of 382516
# copied 318000 samples out of 382516
# copied 319000 samples out of 382516
# copied 320000 samples out of 382516
# copied 321000 samples out of 382516
# copied 322000 samples out of 382516
# copied 323000 samples out of 382516
# copied 324000 samples out of 382516
# copied 325000 samples out of 382516
# copied 326000 samples out of 382516
# copied 327000 samples out of 382516
# copied 328000 samples out of 382516
# copied 329000 samples out of 382516
# copied 330000 samples out of 382516
# copied 331000 samples out of 382516
# copied 332000 samples out of 382516
# copied 333000 samples out of 382516
# copied 334000 samples out of 382516
# copied 335000 samples out of 382516
# copied 336000 samples out of 382516
# copied 337000 samples out of 382516
# copied 338000 samples out of 382516
# copied 339000 samples out of 382516
# copied 340000 samples out of 382516
# copied 341000 samples out of 382516
# copied 342000 samples out of 382516
# copied 343000 samples out of 382516
# copied 344000 samples out of 382516
# copied 345000 samples out of 382516
# copied 346000 samples out of 382516
# copied 347000 samples out of 382516
# copied 348000 samples out of 382516
# copied 349000 samples out of 382516
# copied 350000 samples out of 382516
# copied 351000 samples out of 382516
# copied 352000 samples out of 382516
# copied 353000 samples out of 382516
# copied 354000 samples out of 382516
# copied 355000 samples out of 382516
# copied 356000 samples out of 382516
# copied 357000 samples out of 382516
# copied 358000 samples out of 382516
# copied 359000 samples out of 382516
# copied 360000 samples out of 382516
# copied 361000 samples out of 382516
# copied 362000 samples out of 382516
# copied 363000 samples out of 382516
# copied 364000 samples out of 382516
# copied 365000 samples out of 382516
# copied 366000 samples out of 382516
# copied 367000 samples out of 382516
# copied 368000 samples out of 382516
# copied 369000 samples out of 382516
# copied 370000 samples out of 382516
# copied 371000 samples out of 382516
# copied 372000 samples out of 382516
# copied 373000 samples out of 382516
# copied 374000 samples out of 382516
# copied 375000 samples out of 382516
# copied 376000 samples out of 382516
# copied 377000 samples out of 382516
# copied 378000 samples out of 382516
# copied 379000 samples out of 382516
# copied 380000 samples out of 382516
# copied 381000 samples out of 382516
# copied 382000 samples out of 382516
# copied 382516 samples out of 382516

# %% [markdown]
# # now that the data have been copied, you can make sample sets if you wish

# %%
# function to make new sample set
def make_new_sample_set(set_name, sample_list):
    df_sample_set_table = pd.DataFrame({"membership:sample_set_id" : [set_name]*len(sample_list),
                                    "sample" : sample_list})

    # save to tsv
    sample_set_tsv = set_name + "_sample_set_table.tsv"
    df_sample_set_table.to_csv(sample_set_tsv, sep="\t", index=False)

    # upload to Terra
    response = fapi.upload_entities_tsv(target_ws_project, target_ws_name, sample_set_tsv, model="flexible")
    
    if response.status_code != 200:
        print("ERROR")
        print(response)
        pprint(response.text)
        exit(1)
    else:
        print(f"successfully created new sample_set {set_name} containing {len(sample_list)} samples")

# %%
# Make one big sample set
set_name = "Echo_ScaleTest"
print(f"creating sample set {set_name}...")
make_new_sample_set(set_name, sample_list)

# create batches of samples into sets
# SUBSET_SIZE = 50000


# all_set_samples = sample_list

# subset_number = 0

# new_subset_names = []

# for subset_sample_list in partition_all(SUBSET_SIZE, all_set_samples): 
#     # name the subset
#     subset_number += 1
#     subset_name = f"{set_name}_subset_{subset_number}"
#     print(f"creating sub set {subset_name}...")
#     make_new_sample_set(subset_name, subset_sample_list)
#     new_subset_names.append(subset_name)

# print(new_subset_names)
# Out:
# creating sample set Echo_ScaleTest...
# ERROR
# <Response [502]>
# ('\n'
#  '<html><head>\n'
#  '<meta http-equiv="content-type" content="text/html;charset=utf-8">\n'
#  '<title>502 Server Error</title>\n'
#  '</head>\n'
#  '<body text=#000000 bgcolor=#ffffff>\n'
#  '<h1>Error: Server Error</h1>\n'
#  '<h2>The server encountered a temporary error and could not complete your '
#  'request.<p>Please try again in 30 seconds.</h2>\n'
#  '<h2></h2>\n'
#  '</body></html>\n')
